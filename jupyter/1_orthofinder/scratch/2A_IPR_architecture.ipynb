# %% [markdown]
# # IPR architecture

# %% [markdown]
# ### Workflow:
#
# 1. Create the schemaic table
# 2. Create the domain architecture figure

# %% [markdown]
# ## 1. Create the schematic table

# %% [markdown]
# ### 1.1 Create the scematic table

# %%
# !python /Users/zeyku390/PycharmProjects/H.inflata/jupyter/Annas_script/zeynep/scripts/schematic_arc_table.py --interpro_path '/Users/zeyku390/PycharmProjects/H.inflata/jupyter/1_orthofinder/data/og_diplo_ipr.csv' --out_file_path '/Users/zeyku390/PycharmProjects/H.inflata/jupyter/Annas_script/zeynep/results/schematic_table_og_diplo.csv' --analysis 'Pfam'

# %% [markdown]
# ### 1.2 Display schematic table

# %%
import pandas as pd
d = pd.read_csv('/Users/zeyku390/PycharmProjects/H.inflata/jupyter/Annas_script/zeynep/results/schematic_table_og_diplo.csv', sep='\t', header=None)
d
# Out:
#                     0    1        2    3    4  5             6  \
# 0    Architecture 153  600  PF02493   25  125  1  GL50803_9427
# 1    Architecture 153  600  PF02493  150  250  1  GL50803_9427
# 2    Architecture 153  600  PF02493  275  375  1  GL50803_9427
# 3    Architecture 153  600  PF02493  400  500  1  GL50803_9427
# 4    Architecture 152  450  PF00515   25  125  1    GMRT_11445
# ..                ...  ...      ...  ...  ... ..           ...
# 183    Architecture 5  150  PF00483   25  125  1    TPC1_13543
# 184    Architecture 4  150  PF06705   25  125  1    TPC1_14688
# 185    Architecture 3  150  PF14382   25  125  1    TPC1_14693
# 186    Architecture 2  150  PF01411   25  125  1    TPC1_15884
# 187    Architecture 1  150  PF01878   25  125  1    TPC1_16124
#
#                                                      7
# 0                                          MORN repeat
# 1                                          MORN repeat
# ...

# %% [markdown]
# ## 2 Create domain architecture figure

# %% [markdown]
# ### 2.1 - preprocessing: Create [protein_id, species] file

# %%
import pandas as pd
interproscan_header = ['protein_id','Seq MD5 digest','Sequence length','Analysis', 'Signature accession',
                           'Signature description','Start location', 'Stop location', 'Score', 'Status', 
                           'Date of run', 'Interpro annotations - accession', 'Interpro annotation - description', 
                           'optional: GO terms', 'optional: Pathway annotation']

df_species_group = pd.read_csv('/Users/zeyku390/PycharmProjects/H.inflata/jupyter/1_orthofinder/data/og_diplo_ipr.csv', sep='\t', header=None, names = interproscan_header)
df_species_group = df_species_group.iloc[1:]
df_species_group_pids = df_species_group[['protein_id']].drop_duplicates()
df_species_group_pids['specie'] = df_species_group['protein_id'].str[:2]




df_species_group_pids.to_csv('/Users/zeyku390/PycharmProjects/H.inflata/jupyter/Annas_script/zeynep/results/og_diplo_pids_species.csv', sep='\t', index=False)
df_species_group_pids
# Out:
#        protein_id specie
# 1      HIN_004709     HI
# 5      HIN_004711     HI
# 13     HIN_012689     HI
# 25     HIN_018727     HI
# 28     HIN_018728     HI
# ...           ...    ...
# 11858  TPC1_10881     TP
# 11862  TPC1_14872     TP
# 11864  TPC1_13551     TP
# 11866  TPC1_11163     TP
# 11870  TPC1_16186     TP
#
# [2146 rows x 2 columns]

# %% [markdown]
# ### 2.2 Create domain architecture figure

# %%
# !python /Users/zeyku390/PycharmProjects/H.inflata/jupyter/Annas_script/zeynep/scripts/domain_arc_figure.py --out_file '/Users/zeyku390/PycharmProjects/H.inflata/jupyter/Annas_script/zeynep/results/schematic_figure_og_diplo.png' --interproscan '/Users/zeyku390/PycharmProjects/H.inflata/jupyter/Annas_script/zeynep/results/schematic_table_og_diplo.csv' --analysis 'Pfam' --general_domains 'Yes' --groups_protein_ids '/Users/zeyku390/PycharmProjects/H.inflata/jupyter/Annas_script/zeynep/results/og_diplo_pids_species.csv'

# %% [markdown]
# ### 2.3 Display domain architecture figure

# %%
from IPython.display import Image
Image(filename=('/Users/zeyku390/PycharmProjects/H.inflata/jupyter/Annas_script/zeynep/results/schematic_figure_og_diplo.png'))

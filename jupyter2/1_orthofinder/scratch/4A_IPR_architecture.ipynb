# %% [markdown]
# # IPR architecture

# %% [markdown]
# ### Workflow:
#
# 1. Create the schemaic table
# 2. Create the domain architecture figure

# %% [markdown]
# ## 1. Create the schematic table

# %% [markdown]
# ### 1.1 Create the scematic table

# %%
# !python /Users/zeyku390/PycharmProjects/H.inflata/jupyter/Annas_script/zeynep/scripts/schematic_arc_table.py --interpro_path '/Users/zeyku390/PycharmProjects/H.inflata/jupyter/1_orthofinder/data/og_fl_ipr.csv' --out_file_path '/Users/zeyku390/PycharmProjects/H.inflata/jupyter/Annas_script/zeynep/results/schematic_table_og_fl.csv' --analysis 'Pfam'

# %% [markdown]
# ### 1.2 Display schematic table

# %%
import pandas as pd
d = pd.read_csv('/Users/zeyku390/PycharmProjects/H.inflata/jupyter/Annas_script/zeynep/results/schematic_table_og_fl.csv', sep='\t', header=None)
d
# Out:
#                     0     1        2    3    4  5  \
# 0    Architecture 101  2250  PF02493   25  125  1
# 1    Architecture 101  2250  PF02493  150  250  1
# 2    Architecture 101  2250  PF02493  275  375  1
# 3    Architecture 101  2250  PF02493  400  500  1
# 4    Architecture 101  2250  PF02493  525  625  1
# ..                ...   ...      ...  ...  ... ..
# 249    Architecture 5   150  PF00476   25  125  4
# 250    Architecture 4   150  PF00400   25  125  2
# 251    Architecture 3   150  PF15014   25  125  1
# 252    Architecture 2   150  PF10343   25  125  2
# 253    Architecture 1   150  PF11789   25  125  1
#
#                                                  6  \
# 0                                     KAG9395012.1
# 1                                     KAG9395012.1
# 2                                     KAG9395012.1
# 3                                     KAG9395012.1
# 4                                     KAG9395012.1
# ...

# %% [markdown]
# ## 2 Create domain architecture figure

# %% [markdown]
# ### 2.1 - preprocessing: Create [protein_id, species] file

# %%
import pandas as pd
interproscan_header = ['protein_id','Seq MD5 digest','Sequence length','Analysis', 'Signature accession',
                           'Signature description','Start location', 'Stop location', 'Score', 'Status', 
                           'Date of run', 'Interpro annotations - accession', 'Interpro annotation - description', 
                           'optional: GO terms', 'optional: Pathway annotation']

df_species_group = pd.read_csv('/Users/zeyku390/PycharmProjects/H.inflata/jupyter/1_orthofinder/data/og_fl_ipr.csv', sep='\t', header=None, names = interproscan_header)
df_species_group = df_species_group.iloc[1:]
df_species_group_pids = df_species_group[['protein_id']].drop_duplicates()
df_species_group_pids['specie'] = df_species_group['protein_id'].str[:2]




df_species_group_pids.to_csv('/Users/zeyku390/PycharmProjects/H.inflata/jupyter/Annas_script/zeynep/results/og_fl_pids_species.csv', sep='\t', index=False)
df_species_group_pids
# Out:
#       protein_id specie
# 1     HIN_000257     HI
# 4     HIN_000524     HI
# 7     HIN_000525     HI
# 11    HIN_000537     HI
# 14    HIN_000539     HI
# ...          ...    ...
# 6404  GIQ81284.1     GI
# 6411  GIQ87916.1     GI
# 6416  GIQ88955.1     GI
# 6421  GIQ82005.1     GI
# 6437  GIQ90519.1     GI
#
# [828 rows x 2 columns]

# %% [markdown]
# ### 2.2 Create domain architecture figure

# %%
# !python /Users/zeyku390/PycharmProjects/H.inflata/jupyter/Annas_script/zeynep/scripts/domain_arc_figure.py --out_file '/Users/zeyku390/PycharmProjects/H.inflata/jupyter/Annas_script/zeynep/results/schematic_figure_og_fl.png' --interproscan '/Users/zeyku390/PycharmProjects/H.inflata/jupyter/Annas_script/zeynep/results/schematic_table_og_fl.csv' --analysis 'Pfam' --general_domains 'Yes' --groups_protein_ids '/Users/zeyku390/PycharmProjects/H.inflata/jupyter/Annas_script/zeynep/results/og_fl_pids_species.csv'

# %% [markdown]
# ### 2.3 Display domain architecture figure

# %%
from IPython.display import Image
Image(filename=('/Users/zeyku390/PycharmProjects/H.inflata/jupyter/Annas_script/zeynep/results/schematic_figure_og_fl.png'))
